# %%
# !rm -rf /kaggle/working/*
# %cd /kaggle/working/
# !git clone https://github.com/phanhoang1803/LeNet_Experiment.git
# %cd LeNet_Experiment/src

# %%
## Mnist
# !python main.py \
--mode train \
--dataset mnist \
-lr 0.001 \
--epochs 50 \
--verbose

# !python main.py \
--mode evaluate \
--dataset mnist \
--pretrain-path ../logs/ckpt/checkpoint_lenet_mnist.keras

# %%
## FMnist
# !python main.py \
--mode train \
--dataset fmnist \
-lr 0.001 \
--epochs 50 \
--verbose

# !python main.py \
--mode evaluate \
--dataset fmnist \
--pretrain-path ../logs/ckpt/checkpoint_lenet_fmnist.keras

# %%
## Caltech101
# !python main.py \
--mode train \
--dataset caltech101 \
--raw-dir /kaggle/input/caltech-dataset/101_ObjectCategories/101_ObjectCategories \
-lr 0.001 \
--epochs 50 \
--verbose

# !python main.py \
--mode evaluate \
--dataset caltech101 \
--raw-dir /kaggle/input/caltech-dataset/101_ObjectCategories/101_ObjectCategories \
--pretrain-path ../logs/ckpt/checkpoint_lenet_caltech101.keras

# %%
## Caltech256
# !python main.py \
--mode train \
--dataset caltech256 \
--raw-dir /kaggle/input/caltech-dataset/256_ObjectCategories/256_ObjectCategories \
-lr 0.001 \
--epochs 50 \
--verbose

# !python main.py \
--mode evaluate \
--dataset caltech256 \
--raw-dir /kaggle/input/caltech-dataset/256_ObjectCategories/256_ObjectCategories \
--pretrain-path ../logs/ckpt/checkpoint_lenet_caltech256.keras

# %%
## Finetune Caltech101
# !python main.py \
--mode fine-tune \
--dataset caltech101 \
--raw-dir /kaggle/input/caltech-dataset/101_ObjectCategories/101_ObjectCategories \
-lr 0.0001 \
--epochs 50 \
--verbose \
--pretrain-path /kaggle/input/pretrain-fmnist/checkpoint_lenet_mnist.keras

# !python main.py \
--mode evaluate \
--dataset caltech101 \
--raw-dir /kaggle/input/caltech-dataset/101_ObjectCategories/101_ObjectCategories \
--pretrain-path /kaggle/working/LeNet_Experiment/logs/ckpt/checkpoint_lenet_mnistfinetune_caltech101.keras

# !python main.py \
--mode fine-tune \
--dataset caltech101 \
--raw-dir /kaggle/input/caltech-dataset/101_ObjectCategories/101_ObjectCategories \
-lr 0.0001 \
--epochs 50 \
--verbose \
--pretrain-path /kaggle/input/pretrain-fmnist/checkpoint_lenet_fmnist.keras

# !python main.py \
--mode evaluate \
--dataset caltech101 \
--raw-dir /kaggle/input/caltech-dataset/101_ObjectCategories/101_ObjectCategories \
--pretrain-path /kaggle/working/LeNet_Experiment/logs/ckpt/checkpoint_lenet_fmnistfinetune_caltech101.keras

# %%
## Finetune Caltech256
# !python main.py \
--mode fine-tune \
--dataset caltech256 \
--raw-dir /kaggle/input/caltech-dataset/256_ObjectCategories/256_ObjectCategories \
-lr 0.0001 \
--epochs 50 \
--verbose \
--pretrain-path /kaggle/input/pretrain-fmnist/checkpoint_lenet_mnist.keras

# !python main.py \
--mode evaluate \
--dataset caltech256 \
--raw-dir /kaggle/input/caltech-dataset/256_ObjectCategories/256_ObjectCategories \
--pretrain-path /kaggle/working/LeNet_Experiment/logs/ckpt/checkpoint_lenet_mnistfinetune_caltech256.keras

# !python main.py \
--mode fine-tune \
--dataset caltech256 \
--raw-dir /kaggle/input/caltech-dataset/256_ObjectCategories/256_ObjectCategories \
-lr 0.0001 \
--epochs 50 \
--verbose \
--pretrain-path /kaggle/input/pretrain-fmnist/checkpoint_lenet_fmnist.keras

# !python main.py \
--mode evaluate \
--dataset caltech256 \
--raw-dir /kaggle/input/caltech-dataset/256_ObjectCategories/256_ObjectCategories \
--pretrain-path /kaggle/working/LeNet_Experiment/logs/ckpt/checkpoint_lenet_fmnistfinetune_caltech256.keras

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------

# %%
## Mnist
# !python main.py \
--mode train \
--dataset mnist \
-lr 0.001 \
--epochs 50 \
--model ANN

# !python main.py \
--mode evaluate \
--dataset mnist \
--pretrain-path ../logs/ckpt/checkpoint_ANN_mnist.keras \

# %%
## FMnist
# !python main.py \
--mode train \
--dataset fmnist \
-lr 0.001 \
--epochs 50 \
--model ANN

# !python main.py \
--mode evaluate \
--dataset fmnist \
--pretrain-path ../logs/ckpt/checkpoint_ANN_fmnist.keras

# %%
## Caltech101
# !python main.py \
--mode train \
--dataset caltech101 \
--raw-dir /kaggle/input/caltech-dataset/101_ObjectCategories/101_ObjectCategories \
-lr 0.001 \
--epochs 50 \
--model ANN

# !python main.py \
--mode evaluate \
--dataset caltech101 \
--raw-dir /kaggle/input/caltech-dataset/101_ObjectCategories/101_ObjectCategories \
--pretrain-path ../logs/ckpt/checkpoint_ANN_caltech101.keras

# %%
## Caltech256
# !python main.py \
--mode train \
--dataset caltech256 \
--raw-dir /kaggle/input/caltech-dataset/256_ObjectCategories/256_ObjectCategories \
-lr 0.001 \
--epochs 50 \
--model ANN

# !python main.py \
--mode evaluate \
--dataset caltech256 \
--raw-dir /kaggle/input/caltech-dataset/256_ObjectCategories/256_ObjectCategories \
--pretrain-path ../logs/ckpt/checkpoint_ANN_caltech256.keras

# %%
## Finetune Caltech101
# !python main.py \
--mode fine-tune \
--dataset caltech101 \
--raw-dir /kaggle/input/caltech-dataset/101_ObjectCategories/101_ObjectCategories \
-lr 0.0001 \
--epochs 50 \
--pretrain-path /kaggle/input/pretrain-fmnist/checkpoint_ANN_mnist.keras

# !python main.py \
--mode evaluate \
--dataset caltech101 \
--raw-dir /kaggle/input/caltech-dataset/101_ObjectCategories/101_ObjectCategories \
--pretrain-path /kaggle/working/LeNet_Experiment/logs/ckpt/checkpoint_ANN_mnistfinetune_caltech101.keras

# !python main.py \
--mode fine-tune \
--dataset caltech101 \
--raw-dir /kaggle/input/caltech-dataset/101_ObjectCategories/101_ObjectCategories \
-lr 0.0001 \
--epochs 50 \
--pretrain-path /kaggle/input/pretrain-fmnist/checkpoint_ANN_fmnist.keras

# !python main.py \
--mode evaluate \
--dataset caltech101 \
--raw-dir /kaggle/input/caltech-dataset/101_ObjectCategories/101_ObjectCategories \
--pretrain-path /kaggle/working/LeNet_Experiment/logs/ckpt/checkpoint_ANN_fmnistfinetune_caltech101.keras

# %%
## Finetune Caltech256
# !python main.py \
--mode fine-tune \
--dataset caltech256 \
--raw-dir /kaggle/input/caltech-dataset/256_ObjectCategories/256_ObjectCategories \
-lr 0.0001 \
--epochs 50 \
--pretrain-path /kaggle/input/pretrain-fmnist/checkpoint_ANN_mnist.keras

# !python main.py \
--mode evaluate \
--dataset caltech256 \
--raw-dir /kaggle/input/caltech-dataset/256_ObjectCategories/256_ObjectCategories \
--pretrain-path /kaggle/working/LeNet_Experiment/logs/ckpt/checkpoint_ANN_mnistfinetune_caltech256.keras

# !python main.py \
--mode fine-tune \
--dataset caltech256 \
--raw-dir /kaggle/input/caltech-dataset/256_ObjectCategories/256_ObjectCategories \
-lr 0.0001 \
--epochs 50 \
--pretrain-path /kaggle/input/pretrain-fmnist/checkpoint_ANN_fmnist.keras

# !python main.py \
--mode evaluate \
--dataset caltech256 \
--raw-dir /kaggle/input/caltech-dataset/256_ObjectCategories/256_ObjectCategories \
--pretrain-path /kaggle/working/LeNet_Experiment/logs/ckpt/checkpoint_ANN_fmnistfinetune_caltech256.keras
